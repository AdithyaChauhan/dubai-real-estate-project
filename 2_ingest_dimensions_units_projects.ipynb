# %%
storage_account_name = "REMOVED_FOR_SECURITY"

storage_account_key = "REMOVED_FOR_SECURITY

spark.conf.set(
    f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net",
    storage_account_key
)

# %%
display(
    dbutils.fs.ls(
        "abfss://bronze@adlsdubaiadi.dfs.core.windows.net/units/landing/"
    )
)

# %%
display(
    dbutils.fs.ls(
        "abfss://bronze@adlsdubaiadi.dfs.core.windows.net/projects/landing/"
    )
)

# %%
df_units = spark.read.option("header", True).csv(
    "abfss://bronze@adlsdubaiadi.dfs.core.windows.net/units/landing/current.csv"
)

display(df_units)

# %%
df_projects = spark.read.option("header", True).csv(
    "abfss://bronze@adlsdubaiadi.dfs.core.windows.net/projects/landing/current.csv"
)

display(df_projects)
